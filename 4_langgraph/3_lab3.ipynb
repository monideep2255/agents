# %% [markdown]
# ## Welcome to Week 4, Day 4
#
# This is the start of an AWESOME project! Really simple and very effective.

# %% [markdown]
# ### First - a heads up for Windows PC users
#
# While executing this notebook, you might hit a problem with the Playwright browser raising a NotImplementedError.
#
# This should work when we move to python modules, but it can cause problems in Windows in a notebook.
#
# If you it this error and would like to run the notebook, you need to make a small change which seems quite hacky!
#
# 1. Right click in `.venv` in the File Explorer on the left and select "Find in folder"
# 2. Search for `asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())`
# 3. That code should be found in a line of code in a file called `kernelapp.py`
# 4. Comment out that line of code in that file! And save the file.
# 5. Restart the kernel by pressing the "Restart" button above
#
# Thank you to student Nicolas for finding this, and to Yaki, Zibin and Bhaskar for confirming that this worked for them!

# %%
from typing import Annotated
from typing_extensions import TypedDict
from langgraph.graph import StateGraph, START
from langgraph.graph.message import add_messages
from dotenv import load_dotenv
from IPython.display import Image, display
import gradio as gr
from langgraph.prebuilt import ToolNode, tools_condition
import requests
import os
from langchain.agents import Tool

from langchain_openai import ChatOpenAI
from langgraph.checkpoint.memory import MemorySaver

# %%
load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Asynchronous LangGraph
#
# To run a tool:
# Sync: `tool.run(inputs)`
# Async: `await tool.arun(inputs)`
#
# To invoke the graph:
# Sync: `graph.invoke(state)`
# Async: `await graph.ainvoke(state)`

# %%
class State(TypedDict):
    
    messages: Annotated[list, add_messages]


graph_builder = StateGraph(State)

# %%
pushover_token = os.getenv("PUSHOVER_TOKEN")
pushover_user = os.getenv("PUSHOVER_USER")
pushover_url = "https://api.pushover.net/1/messages.json"

def push(text: str):
    """Send a push notification to the user"""
    requests.post(pushover_url, data = {"token": pushover_token, "user": pushover_user, "message": text})

tool_push = Tool(
        name="send_push_notification",
        func=push,
        description="useful for when you want to send a push notification"
    )

# %% [markdown]
# ### Next: Install Playwright
#
# On Windows and MacOS:
# `playwright install`
#
# On Linux:
# `playwright install —with-reps chromium`

# %% [markdown]
# ### Introducing nest_asyncio
#
# Python async code only allows for one "event loop" processing aynchronous events.
#
# The `nest_asyncio` library patches this, and is used for special situations, if you need to run a nested event loop.

# %%
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# ### The LangChain community
#
# One of the remarkable things about LangChain is the rich community around it.
#
# Check this out:

# %%
from langchain_community.agent_toolkits import PlayWrightBrowserToolkit
from langchain_community.tools.playwright.utils import create_async_playwright_browser

async_browser =  create_async_playwright_browser(headless=False)  # headful mode
toolkit = PlayWrightBrowserToolkit.from_browser(async_browser=async_browser)
tools = toolkit.get_tools()

# %%
for tool in tools:
    print(f"{tool.name}={tool}")
# Out:
# click_element=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/anuradhachakraborti/Library/Caches/ms-playwright/chromium-1169/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=136.0.7103.25>
# navigate_browser=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/anuradhachakraborti/Library/Caches/ms-playwright/chromium-1169/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=136.0.7103.25>
# previous_webpage=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/anuradhachakraborti/Library/Caches/ms-playwright/chromium-1169/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=136.0.7103.25>
# extract_text=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/anuradhachakraborti/Library/Caches/ms-playwright/chromium-1169/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=136.0.7103.25>
# extract_hyperlinks=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/anuradhachakraborti/Library/Caches/ms-playwright/chromium-1169/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=136.0.7103.25>
# get_elements=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/anuradhachakraborti/Library/Caches/ms-playwright/chromium-1169/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=136.0.7103.25>
# current_webpage=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/anuradhachakraborti/Library/Caches/ms-playwright/chromium-1169/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=136.0.7103.25>

# %%
tool_dict = {tool.name:tool for tool in tools}

navigate_tool = tool_dict.get("navigate_browser")
extract_text_tool = tool_dict.get("extract_text")

    
await navigate_tool.arun({"url": "https://www.cnn.com"})
text = await extract_text_tool.arun({})

# %%
import textwrap
print(textwrap.fill(text))
# Out:
# Breaking News, Latest News and Videos | CNN CNN values your feedback
# 1. How relevant is this ad to you? 2. Did you encounter any technical
# issues? No Video player was slow to load content Video content never
# loaded Ad froze or did not finish loading Video content did not start
# after ad Audio on ad was too loud Other issues Ad never loaded Ad
# prevented/slowed the page from loading Content moved around while ad
# loaded Ad was repetitive to ads I've seen previously Other issues
# Cancel Submit Thank You! Your effort and contribution in providing
# this feedback is much
# appreciated. Close Ad Feedback Close icon US World Politics Business
# Health Entertainment Style Travel Sports Science Climate Weather
# Ukraine-Russia War Israel-Hamas War Underscored Games More US World
# Politics Business Health Entertainment Style Travel Sports Science
# Climate Weather Ukraine-Russia War Israel-Hamas War Underscored Games
# Watch Listen Live TV Subscribe Sign in My Account Settings Newsletters
# Topics you follow Sign out Your CNN account Sign in to your CNN
# account Sign in My Account Settings Newsletters Topics you follow Sign
# out Your CNN account Sign in to your CNN account Live TV Listen Watch
# Edition US International Arabic Español Edition US International
# Arabic Español US Crime + Justice World Africa Americas Asia Australia
# China Europe India Middle East United Kingdom Politics Trump Facts
# First CNN Polls 2025 Elections Business Tech Media Calculators Videos
# Markets Pre-markets After-Hours Fear & Greed Investing Markets Now
# Nightcap Health Life, But Better Fitness Food Sleep Mindfulness
# Relationships Entertainment Movies Television Celebrity Tech Innovate
# Foreseeable Future Mission: Ahead Work Transformed Innovative Cities
# Style Arts Design Fashion Architecture Luxury Beauty Video Travel
# Destinations Food & Drink Stay Videos Sports Pro Football College
# Football Basketball Baseball Soccer Olympics Hockey Science Space Life
# Unearthed Climate Solutions Weather Weather Video Climate Ukraine-
# Russia War Israel-Hamas War Watch Live TV CNN Headlines CNN Shorts
# Shows A-Z CNN10 CNN Max CNN TV Schedules FlashDocs Listen CNN 5 Things
# Chasing Life with Dr. Sanjay Gupta The Assignment with Audie Cornish
# One Thing Tug of War CNN Political Briefing The Axe Files All There Is
# with Anderson Cooper All CNN Audio podcasts CNN Underscored
# Electronics Fashion Beauty Health & Fitness Home Reviews Deals Gifts
# Travel Outdoors Pets Games Daily Crossword Jumble Crossword Photo
# Shuffle Sudoblock Sudoku 5 Things Quiz About CNN Subscribe Photos
# Investigations CNN Profiles CNN Leadership CNN Newsletters Work for
# CNN Follow CNN info The top numbered articles will be viewable to
# readers when programmed onto a page. Make sure you have 30 or more
# cards added to the container for the machine learning (ML) feature to
# work. Your queued up articles, seen in the violet section, will use ML
# to surface up relevant content to the reader based on their individual
# interests and preferences. Trending ‘Alligator Alcatraz’ University of
# New Mexico shooting Extreme heat Lori Vallow Daybell Meta Katie
# Ledecky Alaska Airlines ‘Fantastic Four: First Steps’ info The top
# numbered articles will be viewable to readers when programmed onto a
# page. Make sure you have 30 or more cards added to the container for
# the machine learning (ML) feature to work. Your queued up articles,
# seen in the violet section, will use ML to surface up relevant content
# to the reader based on their individual interests and preferences. •
# Analysis Analysis John Minchillo/AP/FILE Analysis Trump just made a
# problematic Ghislaine Maxwell situation look even worse Interviewing
# Ghislaine Maxwell is the Trump administration’s first big move to
# allay concerns about its hugely unpopular handling of the Jeffrey
# Epstein files. Deputy Attorney General Todd Blanche on Friday wrapped
# up two days of interviews with Epstein’s convicted associate. • Live
# Updates Live Updates CNN Live Updates Maxwell was granted limited
# immunity to talk to DOJ, source says Deputy Attorney General Todd
# Blanche will meet with Jeffrey Epstein accomplice Ghislaine Maxwell
# again, as the Trump administration tries to quell weeks of backlash
# over its handling of information on Epstein’s case. Follow for live
# updates. • Video 0:56 CNN Video Maxwell’s attorney shares details of
# meeting with Blanche 0:56 The second day of meetings between Deputy
# Attorney General Todd Blanche, Ghislaine Maxwell and her lawyer has
# finished. Maxwell’s attorney, David Oscar Markus briefly addressed
# reporters saying she “answered every single question” during meetings.
# info The top numbered articles will be viewable to readers when
# programmed onto a page. Make sure you have 30 or more cards added to
# the container for the machine learning (ML) feature to work. Your
# queued up articles, seen in the violet section, will use ML to surface
# up relevant content to the reader based on their individual interests
# and preferences. Kent Nishimura/Getty Images What Powell is telling
# allies as Trump pressures him to resign Federal Reserve Chair Jerome
# Powell has told multiple associates and allies that there’s no chance
# he will bow to President Donald Trump’s calls for him to resign,
# vowing to withstand several more months of the president’s
# unprecedented, multi-pronged assault over Powell’s refusal to lower
# interest rates. • Video 2:12 CNN Video Wall street investors react to
# Trump-Powell squabble 2:12 CNN’s Erin Burnett talks with famed Wall
# Street investors Dan Ives and Peter Tuchman about the awkward moment
# between President Donald Trump and Federal Reserve Chair Jerome Powell
# during their tour of the Fed’s $2.5 billion renovation project. info
# The top numbered articles will be viewable to readers when programmed
# onto a page. Make sure you have 30 or more cards added to the
# container for the machine learning (ML) feature to work. Your queued
# up articles, seen in the violet section, will use ML to surface up
# relevant content to the reader based on their individual interests and
# preferences. Trump tells Israel to 'finish the job' against Hamas
# Show all Chip Somodevilla/Getty Images As Gaza’s starvation crisis
# spirals, US pulled its negotiators after determining Hamas ‘didn’t
# want to make a deal’ Only a few weeks ago, President Donald Trump
# seemed confident a deal was days away that would end the fighting in
# Gaza, secure the release of hostages and allow aid to flow into an
# enclave where people are starving to death. Amir Cohen/Reuters US
# review found no evidence of widespread Hamas theft of Gaza aid An
# internal US government review found no evidence of widespread theft by
# Hamas of US-funded humanitarian aid in Gaza, contradicting the State
# Department’s claims that were used to justify backing a controversial
# private organization that took over aid distribution in the enclave. •
# Live Updates Live Updates Getty Images/AP Live Updates As hunger
# envelops Gaza and ceasefire talks falter, Israel considering
# ‘alternative options’ to return hostages, destroy Hamas Israel and the
# US are recalling negotiators from Gaza ceasefire talks after Hamas
# responded to the latest proposal. Follow for live updates • Video 2:57
# CNN Video Entering Gaza’s sea is forbidden. Fishermen risk their lives
# to get food 2:57 Israel reissued a warning prohibiting anyone from
# entering Gaza’s sea but hunger drives desperate people to fish. CNN’s
# Jeremy Diamond reports. Ahmed Jihad Ibrahim Al-arini/Anadolu/Getty
# Images In pictures: Starvation in Gaza info The top numbered articles
# will be viewable to readers when programmed onto a page. Make sure you
# have 30 or more cards added to the container for the machine learning
# (ML) feature to work. Your queued up articles, seen in the violet
# section, will use ML to surface up relevant content to the reader
# based on their individual interests and preferences. Play CNN
# Headlines - Source: CNN Watch the latest CNN Headlines info The top
# numbered articles will be viewable to readers when programmed onto a
# page. Make sure you have 30 or more cards added to the container for
# the machine learning (ML) feature to work. Your queued up articles,
# seen in the violet section, will use ML to surface up relevant content
# to the reader based on their individual interests and preferences. For
# Subscribers • For Subscribers For Subscribers Jamie Kelter Davis for
# CNN For Subscribers A US war forced her parents to flee. Now, a
# Wisconsin mother has been deported back to the country she never
# called home • For Subscribers For Subscribers TV Zvezda For
# Subscribers Russia lifts lid on secretive drone factory info The top
# numbered articles will be viewable to readers when programmed onto a
# page. Make sure you have 30 or more cards added to the container for
# the machine learning (ML) feature to work. Your queued up articles,
# seen in the violet section, will use ML to surface up relevant content
# to the reader based on their individual interests and preferences.
# AP/Getty Images/Reuters Analysis Democrats are making 2028 moves.
# Here’s what to know Jul 17, 2025 US Marine Corps For Subscribers US
# officers who broke rank to save lives recall the fall of Saigon 50
# years ago Apr 30, 2025 David von Blohn/CNN For Subscribers Meeting
# with a member of one of the most powerful criminal networks in the
# world May 2, 2025 Halfpoint Images/Moment RF/Getty Images Early signs
# of dementia can show in your finances Jul 8, 2024 Massachusetts
# General Hospital For Subscribers Dr. Sanjay Gupta: At the forefront of
# organ transplants, patients are the pioneers May 16, 2025 CNN Video
# China brain tech rivals Musk’s Neuralink 1:35 Jul 20, 2025
# LeoPatrizi/E+/Getty Images Having trouble experiencing joy? This may
# be why Jul 20, 2025 Food Network 12 favorite pasta salad recipes for
# summer Jun 9, 2023 s.ap arkitektar Video See how architects in Iceland
# want to build with molten lava 2:59 Jul 3, 2025 CNN Video ‘Let’s leave
# the country’: A devastating loss led to a new life in Costa Rica 3:32
# Jun 26, 2025 iStock CNN Underscored Hate getting into a hot car? These
# are the 12 best car sun shades in 2025 Jul 8, 2025 CNN Video This home
# was built in a factory and runs on its own energy 3:24 Jun 18, 2025
# Jeremy Harlan/CNN Video Frank-ly, you’re not grilling hot dogs right
# without this water-dunking step 1:02 Jul 1, 2025 cnn Video Meat
# consumption levels are unsustainable. Going vegan isn’t the only
# answer 2:59 Jul 15, 2025 CNN Video How this famous pop star is
# cleaning up the music industry’s environmental practices 1:48 Jul 18,
# 2025 MEGA/GC Images/Getty Images The LA farmer’s market where
# celebrities are as plentiful as the produce Jul 16, 2025
# TikTok/@sed50252, CNN, TikTok/@anchxspider Video Meet the actor behind
# the viral ‘nothing beats a Jet2 holiday’ TikTok sound 1:50 Jul 20,
# 2025 CNN Video This coffee chain overtook Starbucks in China. Now it’s
# open in the US 2:10 Jul 23, 2025 Michelle Rae Uy/CNN Underscored CNN
# Underscored The best personal item bags in 2025, tested and reviewed
# Jul 20, 2025 The Vindolanda Trust Giant shoes found near Hadrian’s
# Wall spark mystery around the soldiers of ancient Rome Jul 12, 2025
# Will McGough/Wake and Wander Media For Subscribers I wanted to scatter
# Dad’s ashes in Antarctica. It didn’t go as planned Feb 24, 2025 Elva
# Etienne/Moment RF/Getty Images Analysis Don’t give children under age
# 13 smartphones, new research says Jul 21, 2025 CNN Video This 6-pound
# backpack changed one man’s approach to life 2:56 Jul 9, 2025 Stacy
# Howell / Food Network Easy grilling recipes to keep in your back
# pocket May 27, 2024 Aaron Lockwood For Subscribers Physical decline is
# common as we age. These exercises can help mitigate the effects Jan
# 29, 2025 Rodrigo Abd/AP For the first time in modern history a capital
# city is on the verge of running dry Jul 19, 2025 Courtesy Collier
# Landry An Ohio doctor killed his wife 36 years ago. As his parole
# hearing nears, his son wrestles with his emotions Apr 27, 2025
# Kosamtu/E+/Getty Images Sugar, sex and your health: The connection you
# might be ignoring Jul 14, 2025 US Immigration and Customs Enforcement
# Americans largely oppose Trump’s ramp-up of deportations, CNN poll
# finds Jul 20, 2025 Illustration by Leah Abucayan/CNN/Adobe Stock For
# Subscribers Forgers and fraudsters trusted him for decades — but he
# was an undercover FBI art detective Apr 27, 2025 info The top numbered
# articles will be viewable to readers when programmed onto a page. Make
# sure you have 30 or more cards added to the container for the machine
# learning (ML) feature to work. Your queued up articles, seen in the
# violet section, will use ML to surface up relevant content to the
# reader based on their individual interests and preferences. More Top
# Stories Allison Robbert/The Washington Post/Getty Images Trump
# administration will release more than $5 billion in frozen education
# funding Former Rep. George Santos reports to prison Video Lead
# investigator reveals what was found on Bryan Kohberger’s phone 0:53
# Cash, gloves and screenshots: Top investigators detail Bryan
# Kohberger’s unusual behavior after Idaho student murders US military
# kills ISIS leader in Syria Video Renowned geneticist says NIH under
# Trump is ‘untenable’ and he and staff were ‘muzzled’ 1:52 info The top
# numbered articles will be viewable to readers when programmed onto a
# page. Make sure you have 30 or more cards added to the container for
# the machine learning (ML) feature to work. Your queued up articles,
# seen in the violet section, will use ML to surface up relevant content
# to the reader based on their individual interests and preferences.
# Immigration • Video 4:54 CNN/Getty Images Video ‘It’s a type of
# torture’: Hear what it’s like inside ‘Alligator Alcatraz’ 4:54 CNN
# talked to immigrants being detained at the Florida facility and
# created a 3D model to explore what conditions are like inside. CNN’s
# Priscilla Alvarez reports. Courtesy Clarissa Fuentes Diaz Pastor and
# father of 3 arrested in Maryland for overstaying visa a quarter-
# century ago A Maryland pastor who fled Honduras 24 years ago to escape
# poverty and violence is waiting to hear when he will face an
# immigration judge after his arrest this week by Immigration and
# Customs Enforcement for overstaying his visa in 2001, his family said.
# info The top numbered articles will be viewable to readers when
# programmed onto a page. Make sure you have 30 or more cards added to
# the container for the machine learning (ML) feature to work. Your
# queued up articles, seen in the violet section, will use ML to surface
# up relevant content to the reader based on their individual interests
# and preferences. space and science NASA The asteroid that will spare
# Earth might hit the moon instead. What happens if it does? Asteroid
# 2024 YR4, which once appeared to be on a collision course with Earth,
# may hit the moon, which could create some problems for our planet. Ad
# Feedback info The top numbered articles will be viewable to readers
# when programmed onto a page. Make sure you have 30 or more cards added
# to the container for the machine learning (ML) feature to work. Your
# queued up articles, seen in the violet section, will use ML to surface
# up relevant content to the reader based on their individual interests
# and preferences. Ad Feedback CNN Underscored Bonne Maman The beloved
# Bonne Maman Advent Calendar just dropped. Grab it before it’s gone Jul
# 21, 2025 Sophie Shaw/CNN Underscored The internet is obsessed with
# TA3’s swimsuits — and now I am too. Here’s why Jul 22, 2025 Kai
# Burkhardt/CNN Underscored We hiked in 28 pairs of pants. These 3 were
# clearly the best Jul 24, 2025 Ad Feedback info The top numbered
# articles will be viewable to readers when programmed onto a page. Make
# sure you have 30 or more cards added to the container for the machine
# learning (ML) feature to work. Your queued up articles, seen in the
# violet section, will use ML to surface up relevant content to the
# reader based on their individual interests and preferences. 'Mini
# Retirement' • For Subscribers For Subscribers SV Open Range For
# Subscribers The money was rolling in for these tech professionals, but
# something was missing • For Subscribers For Subscribers Frame
# Studio/Moment RF/Getty Images For Subscribers Making big financial
# decisions when the world is giving you heartburn Mensent
# Photography/Moment RF/Getty Images Market losses early in retirement
# can increase your risk of outliving your money. But you can take steps
# to mitigate that info The top numbered articles will be viewable to
# readers when programmed onto a page. Make sure you have 30 or more
# cards added to the container for the machine learning (ML) feature to
# work. Your queued up articles, seen in the violet section, will use ML
# to surface up relevant content to the reader based on their individual
# interests and preferences. America's Best Towns Show all Sonoma County
# Tourism Once ‘the world’s egg basket,’ this Gold Rush-era boomtown
# still delivers culinary riches Video Months after Hurricane Helene,
# this mountain town is on the rebound 2:30 Maritime town offers
# boating, great seafood and more than 250 years of history Video This
# Montana town’s top-notch food and world-class wilderness make it a
# must-visit 2:36 info The top numbered articles will be viewable to
# readers when programmed onto a page. Make sure you have 30 or more
# cards added to the container for the machine learning (ML) feature to
# work. Your queued up articles, seen in the violet section, will use ML
# to surface up relevant content to the reader based on their individual
# interests and preferences. For Subscribers • For Subscribers For
# Subscribers Kyle Grillot/Reuters For Subscribers Where the next deadly
# flood wave could strike • For Subscribers For Subscribers CNN For
# Subscribers A secret tunnel city hidden under Rome’s ancient heart is
# being revealed • Analysis Analysis Jacquelyn Martin/Pool/Reuters/File
# Analysis A little snark, a little sarcasm: How dissenting opinions
# catch our attention Ad Feedback Ad Feedback CNN Underscored info The
# top numbered articles will be viewable to readers when programmed onto
# a page. Make sure you have 30 or more cards added to the container for
# the machine learning (ML) feature to work. Your queued up articles,
# seen in the violet section, will use ML to surface up relevant content
# to the reader based on their individual interests and preferences.
# Best-in-class Michelle Rae Uy/CNN Underscored This cat backpack has
# changed my life as a cat mom. Here’s why How to stop your trash can
# from smelling like a dumpster in the summer Unlike AirPods, these
# sleep headphones won’t hurt your ears at night info The top numbered
# articles will be viewable to readers when programmed onto a page. Make
# sure you have 30 or more cards added to the container for the machine
# learning (ML) feature to work. Your queued up articles, seen in the
# violet section, will use ML to surface up relevant content to the
# reader based on their individual interests and preferences. Expert-
# backed guides iStock Sun shades will keep your car’s interior
# temperature comfy. Here are the 12 best After scouring through REI’s
# deal section, here are the 10 best pieces I found Is a foot massager
# worth it? We asked podiatrists for their insights info The top
# numbered articles will be viewable to readers when programmed onto a
# page. Make sure you have 30 or more cards added to the container for
# the machine learning (ML) feature to work. Your queued up articles,
# seen in the violet section, will use ML to surface up relevant content
# to the reader based on their individual interests and preferences.
# Editors' picks Mark Amadio/CNN Underscored 6 expert gardeners shared
# their favorite gardening tools. Here’s what they recommend Sunglasses
# don’t need to be expensive to be high-quality. So we found 16 of the
# best ones The best sales to shop this weekend: Anthropologie, DeWalt,
# Honeywell and more info The top numbered articles will be viewable to
# readers when programmed onto a page. Make sure you have 30 or more
# cards added to the container for the machine learning (ML) feature to
# work. Your queued up articles, seen in the violet section, will use ML
# to surface up relevant content to the reader based on their individual
# interests and preferences. CNN sports Show all Jeff Dean/Getty Images
# Lionel Messi and Inter Miami teammate Jordi Alba suspended after
# skipping MLS All-Star Game NFL to fine more than 100 players and two
# dozen team employees for selling Super Bowl tickets over face value
# Katie Ledecky looks toward ‘exciting’ head to head with Summer
# McIntosh at World Aquatics Championships Tour de France organizers
# shorten stage to avoid diseased cows info The top numbered articles
# will be viewable to readers when programmed onto a page. Make sure you
# have 30 or more cards added to the container for the machine learning
# (ML) feature to work. Your queued up articles, seen in the violet
# section, will use ML to surface up relevant content to the reader
# based on their individual interests and preferences. Bleacher Report
# Show all Wrestling stars pay tribute to Hulk Hogan Greatest moments of
# Hulk Hogan’s career The Rock reacts to Hulk Hogan’s death Win and loss
# predictions for every NFL team this season Fans’ funniest reactions to
# ‘Happy Gilmore 2’ Ad Feedback info The top numbered articles will be
# viewable to readers when programmed onto a page. Make sure you have 30
# or more cards added to the container for the machine learning (ML)
# feature to work. Your queued up articles, seen in the violet section,
# will use ML to surface up relevant content to the reader based on
# their individual interests and preferences. Climate and environment •
# Video 3:07 CNN / Deltec Video Why hurricanes aren’t destroying these
# houses 3:07 Photo illustration by Ian Berry/CNN/Adobe Stock Extreme
# heat is miserable and dangerous. It’s also making us age faster Audrey
# Richardson/Reuters A heat dome is peaking in the Northeast today.
# Here’s how extreme temperatures could get info The top numbered
# articles will be viewable to readers when programmed onto a page. Make
# sure you have 30 or more cards added to the container for the machine
# learning (ML) feature to work. Your queued up articles, seen in the
# violet section, will use ML to surface up relevant content to the
# reader based on their individual interests and preferences. World
# Show all Clarens Siffroy/AFP via Getty Images Haiti sends troops to
# Mexico for training as gang violence rages on A man in India ran a
# fake embassy, Indian police say How a Venezuelan migrant kept faith
# alive in Salvadoran prison ‘hell’ Toasting the god of destruction and
# renewal, these Hindu pilgrims party hard. Not everyone is thrilled.
# info The top numbered articles will be viewable to readers when
# programmed onto a page. Make sure you have 30 or more cards added to
# the container for the machine learning (ML) feature to work. Your
# queued up articles, seen in the violet section, will use ML to surface
# up relevant content to the reader based on their individual interests
# and preferences. Latest Politics Show all Jamie McCarthy/MG21/Getty
# Images House Ethics report finds AOC ‘impermissibly accepted gifts’
# related to 2021 Met Gala appearance Trump signs executive order making
# it easier to remove homeless people from streets Two senior NOAA
# officials were just placed on leave. Both led ‘Sharpiegate’ inquiry
# CNN Exclusive FEMA aims to cut nearly $1 billion in emergency
# management and homeland security grants info The top numbered articles
# will be viewable to readers when programmed onto a page. Make sure you
# have 30 or more cards added to the container for the machine learning
# (ML) feature to work. Your queued up articles, seen in the violet
# section, will use ML to surface up relevant content to the reader
# based on their individual interests and preferences. business Show all
# Rebecca Wright/CNN Is this even legal? Answers to every question about
# the Tea app drama How Trump’s mass deportations could backfire on the
# American economy by shrinking paychecks There’s a sweet spot for
# tariffs. Markets could revolt if Trump is way off Meta is shelling out
# big bucks to get ahead in AI. Here’s who it’s hiring info The top
# numbered articles will be viewable to readers when programmed onto a
# page. Make sure you have 30 or more cards added to the container for
# the machine learning (ML) feature to work. Your queued up articles,
# seen in the violet section, will use ML to surface up relevant content
# to the reader based on their individual interests and preferences.
# Life, But Greener Show all • Video 2:36 TikTok / @seht876 /
# @geiamendozaaa / @seht876 Video This Swiss river is so clean, locals
# use it to commute to work 2:36 • Video 1:48 CNN Video Why Billie
# Eilish insists on special rules at all her concerts 1:48 • Video 2:57
# CNN Video More than a million poop bags end up in landfills - how your
# pet impacts the planet 2:57 info The top numbered articles will be
# viewable to readers when programmed onto a page. Make sure you have 30
# or more cards added to the container for the machine learning (ML)
# feature to work. Your queued up articles, seen in the violet section,
# will use ML to surface up relevant content to the reader based on
# their individual interests and preferences. US news Show all Tony
# Blakeslee/Pool/EastIdahoNews.com/AP/File Lori Vallow Daybell receives
# life in prison for 2 Arizona murder conspiracy convictions Police
# search for suspect after shooting on University of New Mexico campus
# leaves 1 dead 9-year-old dies after incident at Hersheypark’s water
# park in Pennsylvania info The top numbered articles will be viewable
# to readers when programmed onto a page. Make sure you have 30 or more
# cards added to the container for the machine learning (ML) feature to
# work. Your queued up articles, seen in the violet section, will use ML
# to surface up relevant content to the reader based on their individual
# interests and preferences. Health and Wellness Show all • Analysis
# Analysis vgajic/E+/Getty Images/File Analysis Here’s why teens don’t
# belong on dating apps States, cities face loss of vaccination programs
# and staff after ‘baffling’ cuts to federal funding Video Breast cancer
# rates are rising, could alcohol consumption be the cause? 2:52 info
# The top numbered articles will be viewable to readers when programmed
# onto a page. Make sure you have 30 or more cards added to the
# container for the machine learning (ML) feature to work. Your queued
# up articles, seen in the violet section, will use ML to surface up
# relevant content to the reader based on their individual interests and
# preferences. Art and style Show all Sansho Scott/BFA.com/Shutterstock
# Artist Amy Sherald cancels major exhibition over portrait of trans
# State of Liberty Has Ozempic flattened the chunky shoe trend? Prada
# ‘sandal scandal’ demonstrates luxury fashion’s India dilemma info The
# top numbered articles will be viewable to readers when programmed onto
# a page. Make sure you have 30 or more cards added to the container for
# the machine learning (ML) feature to work. Your queued up articles,
# seen in the violet section, will use ML to surface up relevant content
# to the reader based on their individual interests and preferences.
# Entertainment and Culture Show all • Analysis Analysis Marvel Studios
# Analysis Marvel finally made a movie you don’t need a guide to follow
# Analysis Comedy shows kept laughter, and free speech, alive this week
# GloRilla charged with possession after police respond to her home to
# investigate burglary Paid Content More from CNN info The top numbered
# articles will be viewable to readers when programmed onto a page. Make
# sure you have 30 or more cards added to the container for the machine
# learning (ML) feature to work. Your queued up articles, seen in the
# violet section, will use ML to surface up relevant content to the
# reader based on their individual interests and preferences. Travel and
# tourism Show all Jenny Kane/AP Alaska Airlines plane hits multiple
# deer while landing in Kodiak, Alaska. It’s more common than you might
# think Ingus Kruklitis/Alamy Stock Photo ‘Haunted’ Venice island to
# become a locals-only haven where tourists are banned • Video 2:46 CNN
# Video See ancient tunnels that go 75 feet under Rome 2:46 info The top
# numbered articles will be viewable to readers when programmed onto a
# page. Make sure you have 30 or more cards added to the container for
# the machine learning (ML) feature to work. Your queued up articles,
# seen in the violet section, will use ML to surface up relevant content
# to the reader based on their individual interests and preferences.
# Week in review • Gallery Gallery Hollie Adams/Reuters Gallery Lava
# flows from volcano. Swimmer competes in open-water race. The week in
# photos • Quiz Quiz Getty Images Quiz The average score for this week’s
# news quiz is 6.5. Can you do better? • Look of the Week Look of the
# Week Click News and Media Look of the Week Charli XCX is the anti-
# bride Ad Feedback Paid Partner Content info The top numbered articles
# will be viewable to readers when programmed onto a page. Make sure you
# have 30 or more cards added to the container for the machine learning
# (ML) feature to work. Your queued up articles, seen in the violet
# section, will use ML to surface up relevant content to the reader
# based on their individual interests and preferences. CNN Games +
# Quizzes Show all • Today's crossword Today's crossword CNN Today's
# crossword No pencil or eraser required • Sudoblock Sudoblock CNN
# Sudoblock Sudoku + Blocks = addictive tile-matching puzzle • Jumble
# Crossword Jumble Crossword CNN Jumble Crossword Test your smarts with
# this scrambled word game • Weekly news quiz Weekly news quiz cnn
# Weekly news quiz What do you remember from the week that was? In case
# you missed it info The top numbered articles will be viewable to
# readers when programmed onto a page. Make sure you have 30 or more
# cards added to the container for the machine learning (ML) feature to
# work. Your queued up articles, seen in the violet section, will use ML
# to surface up relevant content to the reader based on their individual
# interests and preferences. Rebecca Blackwell/AP Deportation flights
# from ‘Alligator Alcatraz’ begin as Florida vows a ‘surge’ of
# immigration arrests info The top numbered articles will be viewable to
# readers when programmed onto a page. Make sure you have 30 or more
# cards added to the container for the machine learning (ML) feature to
# work. Your queued up articles, seen in the violet section, will use ML
# to surface up relevant content to the reader based on their individual
# interests and preferences. Ex-Biden chief of staff told congressional
# staffers that Clinton, Sullivan raised concerns about Biden’s waning
# support Trump administration sues New York City over its ‘sanctuary
# city’ policies Travelers hail end of visa freeze between world’s two
# most populous nations as diplomatic tensions thaw Wrongfully
# imprisoned Maryland man who spent 32 years behind bars sues former
# authorities ‘The weak treating the weak’: Doctors in Gaza are fainting
# while trying to save their starving patients Why Europeans don’t put
# ice in their drinks New Jersey Little Leaguer cleared to play after
# being suspended for ‘unsportsmanlike’ bat flip Subscribe Sign in My
# Account Settings Newsletters Topics you follow Sign out Your CNN
# account Sign in to your CNN account Live TV Listen Watch US Crime +
# Justice World Africa Americas Asia Australia China Europe India Middle
# East United Kingdom Politics Trump Facts First CNN Polls 2025
# Elections Business Tech Media Calculators Videos Markets Pre-markets
# After-Hours Fear & Greed Investing Markets Now Nightcap Health Life,
# But Better Fitness Food Sleep Mindfulness Relationships Entertainment
# Movies Television Celebrity Tech Innovate Foreseeable Future Mission:
# Ahead Work Transformed Innovative Cities Style Arts Design Fashion
# Architecture Luxury Beauty Video Travel Destinations Food & Drink Stay
# News Videos Sports Pro Football College Football Basketball Baseball
# Soccer Olympics Hockey Science Space Life Unearthed Climate Solutions
# Weather Weather Video Climate Ukraine-Russia War Israel-Hamas War
# Watch Live TV CNN Headlines CNN Shorts Shows A-Z CNN10 CNN Max CNN TV
# Schedules FlashDocs Listen CNN 5 Things Chasing Life with Dr. Sanjay
# Gupta The Assignment with Audie Cornish One Thing Tug of War CNN
# Political Briefing The Axe Files All There Is with Anderson Cooper All
# CNN Audio podcasts CNN Underscored Electronics Fashion Beauty Health &
# Fitness Home Reviews Deals Gifts Travel Outdoors Pets Games Daily
# Crossword Jumble Crossword Photo Shuffle Sudoblock Sudoku 5 Things
# Quiz About CNN Subscribe Photos Investigations CNN Profiles CNN
# Leadership CNN Newsletters Work for CNN Watch Listen Live TV Follow
# CNN Subscribe Sign in My Account Settings Newsletters Topics you
# follow Sign out Your CNN account Sign in to your CNN account Terms of
# Use Privacy Policy Do Not Sell Or Share My Personal Information Ad
# Choices Accessibility & CC About Subscribe Newsletters Transcripts
# Help Center © 2025 Cable News Network. A Warner Bros. Discovery
# Company. All Rights Reserved. CNN Sans ™ & © 2016 Cable News Network.
# Global Privacy Control (GPC) signal detected.  Your personal
# information will not be sold or shared. Do Not Sell or Share My
# Personal Data For residents of certain states only.  Please visit our
# U.S. State Supplement for more information. Privacy Policy Manage
# Consent Preferences Allow the Sale, Sharing or use of My Personal
# information for Targeted Advertising Allow the Sale, Sharing or use of
# My Personal information for Targeted Advertising If you switch this
# toggle to “no,” we will not sell or share your personal information
# with third parties for advertising targeted to this device. Please see
# our Privacy Center for additional preferences. Strictly Necessary
# Cookies Always Active These cookies are necessary for the website to
# function and cannot be switched off in our systems. You can set your
# browser to block or alert you about these cookies, but some parts of
# the site will not work. Back Button Cookie List Search Icon Filter
# Icon Clear checkbox label label Apply Cancel Consent Leg.Interest
# checkbox label label checkbox label label checkbox label label Confirm
# My Choices Legal Terms and Privacy By clicking "Agree", you have read
# and agree to the Terms of Use and agree to the collection and use of
# your information by cookies and similar technologies, as set forth in
# our Privacy Policy . Agree

# %%
all_tools = tools + [tool_push]

# %%
llm = ChatOpenAI(model="gpt-4o-mini")
llm_with_tools = llm.bind_tools(all_tools)


def chatbot(state: State):
    return {"messages": [llm_with_tools.invoke(state["messages"])]}

# %%
graph_builder = StateGraph(State)
graph_builder.add_node("chatbot", chatbot)
graph_builder.add_node("tools", ToolNode(tools=all_tools))
graph_builder.add_conditional_edges( "chatbot", tools_condition, "tools")
graph_builder.add_edge("tools", "chatbot")
graph_builder.add_edge(START, "chatbot")

memory = MemorySaver()
graph = graph_builder.compile(checkpointer=memory)
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
config = {"configurable": {"thread_id": "10"}}

async def chat(user_input: str, history):
    result = await graph.ainvoke({"messages": [{"role": "user", "content": user_input}]}, config=config)
    return result["messages"][-1].content


gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
